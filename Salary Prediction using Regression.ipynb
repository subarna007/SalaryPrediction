# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Salary Data.csv')

# %%
dataset
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
dataset = dataset.dropna()     #drops rows having empty value or NAN value
dataset
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 6 columns]

# %%
dataset = dataset[['Years of Experience','Salary']]
dataset
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1:].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
viz_train = plt
viz_train.scatter(X_train,y_train,color = 'red')
viz_train.plot(X_train,regressor.predict(X_train),color = 'blue')
viz_train.title('Salary vs Experience(Training set)')
viz_train.xlabel('Years of Experience')
viz_train.ylabel('Salary')
viz_train.show()

# %%
viz_test = plt
viz_test.scatter(X_test,y_test,color = 'red')
viz_test.plot(X_train,regressor.predict(X_train),color = 'blue')
viz_test.title('Salary vs Experience(Test set)')
viz_test.xlabel('Years of Experience')
viz_test.ylabel('Salary')
viz_test.show()

# %%
y_pred = regressor.predict(np.array([[5]]))
print("Predicted salary for 5 years of experience:", y_pred)
# Out:
# Predicted salary for 5 years of experience: [[66077.71199377]]

# %%
#testing model
exp = float(input("Enter years of experience = "))
exp = np.array([[exp]])
print(exp)

# # # # predict the salary
predicted_salary = regressor.predict(exp)
# print(predicted_salary)
print("Your predicted_salary = ",predicted_salary)
# Out:
# Enter years of experience = 6
# [[6.]]
# Your predicted_salary =  [[72984.36653098]]

# %%
predicted_salary = regressor.predict(X_test)
for i in range(len(X_test)):
  print(X_test.tolist()[i][0],y_test.tolist()[i][0],predicted_salary[i][0])
# Out:
# 2.0 40000.0 45357.74838215728
# 2.0 40000.0 45357.74838215728
# 3.0 50000.0 52264.40291936234
# 16.0 140000.0 142050.91190302806
# 8.0 85000.0 86797.67560538762
# 16.0 140000.0 142050.91190302806
# 4.0 60000.0 59171.057456567396
# 14.0 115000.0 128237.60282861795
# 2.0 40000.0 45357.74838215728
# 21.0 190000.0 176584.18458905333
# 5.0 70000.0 66077.71199377245
# 12.0 130000.0 114424.29375420784
# 15.0 150000.0 135144.257365823
# 7.0 105000.0 79891.02106818257
# 11.0 120000.0 107517.63921700278
# 4.0 60000.0 59171.057456567396
# 3.0 45000.0 52264.40291936234
# 2.0 40000.0 45357.74838215728
# 16.0 150000.0 142050.91190302806
# 20.0 180000.0 169677.53005184827
# 8.0 90000.0 86797.67560538762
# 8.0 95000.0 86797.67560538762
# 10.0 120000.0 100610.98467979772
# 2.0 40000.0 45357.74838215728
# 23.0 170000.0 190397.49366346345
# 2.0 40000.0 45357.74838215728
# 5.0 45000.0 66077.71199377245
# 5.0 50000.0 66077.71199377245
# 12.0 120000.0 114424.29375420784
# 3.0 65000.0 52264.40291936234
# 5.0 70000.0 66077.71199377245
# 12.0 100000.0 114424.29375420784
# 12.0 100000.0 114424.29375420784
# 15.0 120000.0 135144.257365823
# 3.0 45000.0 52264.40291936234
# 12.0 130000.0 114424.29375420784
# 3.0 75000.0 52264.40291936234
# 11.0 110000.0 107517.63921700278
# 10.0 90000.0 100610.98467979772
# 12.0 60000.0 114424.29375420784
# 14.0 120000.0 128237.60282861795
# 19.0 150000.0 162770.8755146432
# 16.0 125000.0 142050.91190302806
# 20.0 180000.0 169677.53005184827
# 19.0 170000.0 162770.8755146432
# 2.0 55000.0 45357.74838215728
# 6.0 55000.0 72984.36653097751
# 18.0 105000.0 155864.22097743815
# 4.0 80000.0 59171.057456567396
# 8.0 90000.0 86797.67560538762
# 9.0 120000.0 93704.33014259266
# 9.0 95000.0 93704.33014259266
# 7.0 100000.0 79891.02106818257
# 8.0 95000.0 86797.67560538762
# 5.0 80000.0 66077.71199377245
# 20.0 180000.0 169677.53005184827
# 8.0 90000.0 86797.67560538762
# 2.0 40000.0 45357.74838215728
# 2.0 40000.0 45357.74838215728
# 3.0 50000.0 52264.40291936234
# 3.0 45000.0 52264.40291936234
# 22.0 160000.0 183490.8391262584
# 16.0 150000.0 142050.91190302806
# 2.0 40000.0 45357.74838215728
# 1.0 35000.0 38451.09384495223
# 9.0 95000.0 93704.33014259266
# 8.0 95000.0 86797.67560538762
# 19.0 170000.0 162770.8755146432
# 1.5 50000.0 41904.42111355476
# 15.0 150000.0 135144.257365823
# 2.0 65000.0 45357.74838215728
# 1.0 45000.0 38451.09384495223
# 9.0 110000.0 93704.33014259266
# 1.5 35000.0 41904.42111355476
# 20.0 180000.0 169677.53005184827
# 3.0 50000.0 52264.40291936234
# 5.0 50000.0 66077.71199377245
# 8.0 85000.0 86797.67560538762
# 21.0 180000.0 176584.18458905333
# 10.0 55000.0 100610.98467979772
# 3.0 55000.0 52264.40291936234
# 13.0 80000.0 121330.94829141289
# 2.0 40000.0 45357.74838215728
# 2.0 40000.0 45357.74838215728
# 2.0 35000.0 45357.74838215728
# 19.0 190000.0 162770.8755146432
# 8.0 95000.0 86797.67560538762
# 3.0 45000.0 52264.40291936234
# 0.0 35000.0 31544.439307747176
# 3.0 50000.0 52264.40291936234
# 1.5 45000.0 41904.42111355476
# 4.0 50000.0 59171.057456567396
# 3.0 50000.0 52264.40291936234
# 17.0 155000.0 148957.56644023312
# 2.0 40000.0 45357.74838215728
# 20.0 170000.0 169677.53005184827
# 2.0 50000.0 45357.74838215728
# 6.0 100000.0 72984.36653097751
# 21.0 180000.0 176584.18458905333
# 14.0 110000.0 128237.60282861795
# 13.0 110000.0 121330.94829141289
# 18.0 150000.0 155864.22097743815
# 19.0 120000.0 162770.8755146432
# 19.0 170000.0 162770.8755146432
# 6.0 65000.0 72984.36653097751
# 8.0 95000.0 86797.67560538762
# 8.0 110000.0 86797.67560538762
# 13.0 120000.0 121330.94829141289
# 16.0 150000.0 142050.91190302806
# 9.0 100000.0 93704.33014259266
# 12.0 115000.0 114424.29375420784
# 10.0 120000.0 100610.98467979772
# 19.0 140000.0 162770.8755146432
# 6.0 90000.0 72984.36653097751
# 23.0 185000.0 190397.49366346345
# 10.0 110000.0 100610.98467979772
# 0.5 35000.0 34997.766576349706
# 9.0 100000.0 93704.33014259266
# 5.0 50000.0 66077.71199377245
# 15.0 150000.0 135144.257365823
# 20.0 180000.0 169677.53005184827
# 21.0 180000.0 176584.18458905333
# 1.0 35000.0 38451.09384495223
# 15.0 65000.0 135144.257365823
# 17.0 160000.0 148957.56644023312

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=6)
# poly_reg.fit(X, y)
X_poly = poly_reg.fit_transform(X)

pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualizing the Polymonial Regression results

plt.scatter(X, y, color='cyan')
plt.plot(X, pol_reg.predict(X_poly), color='magenta')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
